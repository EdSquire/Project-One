# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
df_combine = pd.read_pickle(r'C:\Users\admin\OneDrive - Aero Operating LLC\Documents\Prepared Data\orders_products_combined.pkl')

# %%
path = r'C:\Users\admin\OneDrive - Aero Operating LLC\Documents\Prepared Data'

# %%
path
# Out:
# 'C:\\Users\\admin\\OneDrive - Aero Operating LLC\\Documents\\Prepared Data'

# %%
df_ords_prod_comb = pd.read_pickle(os.path.join(path, 'orders_products_combined.pkl'))

# %%
df_ords_prod_comb
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 32434484   2977660   206209    prior            13          1
# 32434485   2977660   206209    prior            13          1
# 32434486   2977660   206209    prior            13          1
# 32434487   2977660   206209    prior            13          1
# 32434488   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %%
# Question 4. Checking the shape

# %%
df_ords_prod_comb.shape
# Out:
# (32434489, 11)

# %%
df_prods = pd.read_csv(r'C:\Users\admin\OneDrive - Aero Operating LLC\Documents\Original Data\products.csv', index_col = False)

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
# Question 5. Combine the orders_products_combined table with the products table on the shared product_id coulmn

# %%
df_ord_prod_merged = df_ords_prod_comb.merge(df_prods, on = 'product_id')

# %%
df_ord_prod_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices
# ...

# %%
# Question 6. Combined and results checcked

# %%
df_ord_prod_merged['_merge'].value_counts()
# Out:
# both          32434212
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_ord_prod_merged.shape
# Out:
# (32434212, 15)

# %%
# Question 7. Export new data frame

# %%
# Export data to pkl

df_ord_prod_merged.to_pickle(os.path.join(path, 'orders_products_merged.pkl'))
