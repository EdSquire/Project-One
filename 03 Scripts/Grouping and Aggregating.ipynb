# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
df_merged_two = pd.read_pickle(r'C:\Users\admin\OneDrive - Aero Operating LLC\Documents\Prepared Data\orders_products_merged_two.pkl')

# %%
path = r'C:\Users\admin\OneDrive - Aero Operating LLC\Documents\Prepared Data'

# %%
path
# Out:
# 'C:\\Users\\admin\\OneDrive - Aero Operating LLC\\Documents\\Prepared Data'

# %%
df_merged_two
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2398795        1    prior             2          3
# 2           473747        1    prior             3          3
# 3          2254736        1    prior             4          4
# 4           431534        1    prior             5          4
# ...            ...      ...      ...           ...        ...
# 32434207   1320836   202557    prior            17          2
# 32434208     31526   202557    prior            18          5
# 32434209    758936   203436    prior             1          2
# 32434210   2745165   203436    prior             2          3
# 32434211   3093936   205420    prior             1          4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# ...

# %%
df_million = df_merged_two[:1000000]

# %%
df_million.shape
# Out:
# (1000000, 21)

# %%
df_million.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     NaN         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
#   product_name aisle_id  department_id  prices    price_range_loc  \
# ...

# %%
df_million.groupby('product_name')

# %%
df_million.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df_million.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df_million.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
df_million['max_order'] = df_million.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_2532\2018331183.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_million['max_order'] = df_million.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_million.head(15)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   2968173       15    prior            15          1                  9
# ...

# %%
pd.options.display.max_rows = None

# %%
df_million.head(100)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# ..       ...      ...      ...           ...        ...                ...
# 95   3226575      360    prior             1          5                 12
# 96   1469869      377    prior             3          5                 17
# 97   1927023      387    prior             2          4                 10
# 98    858092      420    prior             4          1                 19
# 99    119314      420    prior             5          3                 19
#
# ...

# %%
df_million.loc[df_million['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_million.loc[(df_million['max_order'] <= 40) & (df_million['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_million.loc[df_million['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_million['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    463844
# Loyal customer      335086
# New customer        201070
# Name: loyalty_flag, dtype: int64

# %%
df_million[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %% [markdown]
# # Task 4.8

# %%
# Question 2.Entire Dataframe

# %%
df_merged_two.groupby('product_name')

# %%
df_merged_two.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457687
# 2                17.277920
# 3                17.179756
# 4                17.811403
# 5                15.213779
# 6                16.439806
# 7                17.225773
# 8                15.340520
# 9                15.895474
# 10               20.197148
# 11               16.170828
# 12               15.887622
# 13               16.583304
# 14               16.757377
# 15               16.165037
# 16               17.663250
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %%
# Check

# %%
df_merged_two.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457687
# 2     17.277920
# 3     17.179756
# 4     17.811403
# 5     15.213779
# 6     16.439806
# 7     17.225773
# 8     15.340520
# 9     15.895474
# 10    20.197148
# 11    16.170828
# 12    15.887622
# 13    16.583304
# 14    16.757377
# 15    16.165037
# 16    17.663250
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %%
# Question 3. The 1,000,000 row dataframe returns results from only 8 departments while the entire dataframe returns results from all 21 departments

# %%
# Question 4. Loyalty flag for Entire database

# %%
df_merged_two['max_order'] = df_merged_two.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_merged_two.head(20)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   2968173       15    prior            15          1                  9
# ...

# %%
df_merged_two.loc[df_merged_two['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_merged_two.loc[(df_merged_two['max_order'] <= 40) & (df_million['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_merged_two.loc[df_merged_two['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_merged_two['loyalty_flag'].value_counts(dropna = False)
# Out:
# NaN                 15415137
# Loyal customer      10273708
# New customer         6281523
# Regular customer      463844
# Name: loyalty_flag, dtype: int64

# %%
df_merged_two[['user_id', 'loyalty_flag', 'order_number']].head(30)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %%
df_merged_two.groupby('loyalty_flag').agg({'order_number': ['mean']})
# Out:
#                  order_number
#                          mean
# loyalty_flag
# Loyal customer      32.667599
# New customer         3.813105
# Regular customer    13.531575

# %%
# Question 5. Loyal Customers average order of $32.64 is much higer than the Regular Customer average order of $13.30 and New Customer average order of $3.81

# %%
# Question 6. High Spender and Low Spender flags

# %%
df_merged_two['avg_price'] = df_merged_two.groupby(['user_id'])['prices'].transform(np.max)

# %%
df_merged_two.loc[df_merged_two['avg_price'] >= 10, 'loyalty_flag'] = 'High Spender'

# %%
df_merged_two.loc[df_merged_two['avg_price'] < 10, 'loyalty_flag'] = 'Low Spender'

# %%
df_merged_two['loyalty_flag'].value_counts(dropna = False)
# Out:
# High Spender    32402635
# Low Spender        31577
# Name: loyalty_flag, dtype: int64

# %%
# Question 7. Frequent and infrequent customers

# %%
df_merged_two['frequency'] = df_merged_two.groupby(['user_id'])['days_since_prior_order'].transform(np.max)

# %%
df_merged_two.loc[df_merged_two['frequency'] > 20, 'loyalty_flag'] = 'Non Frequent Customer'

# %%
df_merged_two.loc[df_merged_two['frequency'] < 10, 'loyalty_flag'] = 'Frequent Customer'

# %%
df_merged_two.loc[(df_merged_two['frequency'] < 20) & (df_merged_two['frequency'] > 10), 'loyalty_flag'] = 'Regular Customer'

# %%
df_merged_two['frequency'].value_counts(dropna = False)
# Out:
# 30.0    18370537
# 21.0      989726
# 14.0      906962
# 15.0      898176
# 22.0      836753
# 28.0      823789
# 20.0      748747
# 16.0      658061
# 23.0      643292
# 17.0      642898
# 19.0      621802
# 29.0      605175
# 18.0      604998
# 27.0      599552
# 13.0      586567
# 25.0      556152
# 24.0      550907
# 26.0      533737
# 12.0      471730
# 11.0      399530
# 10.0      374091
# 9.0       308398
# 8.0       287046
# 7.0       195228
# 6.0        81839
# 5.0        76466
# 4.0        43815
# 3.0        11119
# 2.0         5438
# 1.0         1326
# 0.0          355
# Name: frequency, dtype: int64

# %%
# Export data to pkl

df_merged_two.to_pickle(os.path.join(path, 'orders_products_merged_three.pkl'))

# %%
df_merged_two.loc[df_merged_two['prices'] >100, 'prices'] = np.nan
